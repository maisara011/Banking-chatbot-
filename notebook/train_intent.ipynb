# %%
# pip install ipywidgets

# %%
import json
import torch
import numpy as np
import json

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments
)

# %%
with open("../nlu_engine/intents.json", "r", encoding="utf-8") as f:
    data = json.load(f)

texts = []
labels = []

label2id = {intent["name"]: i for i, intent in enumerate(data["intents"])}
id2label = {i: name for name, i in label2id.items()}

for intent in data["intents"]:
    for example in intent["examples"]:
        texts.append(example)
        labels.append(label2id[intent["name"]])

# %%
print(f"Total examples: {len(texts)}")
display(texts[:5])
# Out:
# Total examples: 80
# ["What's my account balance?",
#  'Show balance for my savings account',
#  'How much money do I have in my current account?',
#  'Check balance of my savings',
#  'Can you tell me my account balance?']

# %%
print(f"Total labels: {len(set(labels))}")
# Out:
# Total labels: 4

# %%
shown_labels = len(label2id)
print(f"Shown labels: {shown_labels}")
print(f"Label to ID mapping: {label2id}")
print(f"ID to Label mapping: {id2label}")
# Out:
# Shown labels: 4
# Label to ID mapping: {'check_balance': 0, 'transfer_money': 1, 'card_block': 2, 'find_atm': 3}
# ID to Label mapping: {0: 'check_balance', 1: 'transfer_money', 2: 'card_block', 3: 'find_atm'}

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(texts,labels,test_size=0.2,random_state=42)

# %%
MODEL_NAME = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /distilbert-base-uncased/resolve/main/tokenizer_config.json (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018B579E70E0>: Failed to resolve \'huggingface.co\' ([Errno 11002] getaddrinfo failed)"))'), '(Request ID: 13b06434-7e30-43e5-b132-8906e5828ff8)')' thrown while requesting HEAD https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /distilbert-base-uncased/resolve/main/tokenizer_config.json (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018B579F6490>: Failed to resolve \'huggingface.co\' ([Errno 11002] getaddrinfo failed)"))'), '(Request ID: 42d95c06-70dd-41df-b3eb-b685fb094348)')' thrown while requesting HEAD https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json
# Retrying in 2s [Retry 2/5].
# '(MaxRetryError('HTTPSConnectionPool(host=\'huggingface.co\', port=443): Max retries exceeded with url: /distilbert-base-uncased/resolve/main/tokenizer_config.json (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018B579F6990>: Failed to resolve \'huggingface.co\' ([Errno 11002] getaddrinfo failed)"))'), '(Request ID: 14a4b65e-de2a-47e6-8ff4-4207881d145d)')' thrown while requesting HEAD https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json
# Retrying in 4s [Retry 3/5].

# %%
def tokenize(texts, labels):
    encodings = tokenizer(
        texts,
        truncation=True,
        padding=True,
        max_length=128,
        return_tensors="pt"
    )
    encodings["labels"] = torch.tensor(labels)
    return encodings

# %%
class IntentDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __len__(self):
        return len(self.encodings["labels"])

    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.encodings.items()}

# %%
train_encodings = tokenize(train_texts, train_labels)
val_encodings = tokenize(val_texts, val_labels)

train_dataset = IntentDataset(train_encodings)
val_dataset = IntentDataset(val_encodings)

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=len(label2id)
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="../models/intent_model_2",
    num_train_epochs=100,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    learning_rate=2e-5,  # 0.00002
    logging_dir="../models/intent_model_2/logs",
    do_eval=True,
    save_steps=500
)

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=1)

    return {
        "accuracy": accuracy_score(labels, predictions),
        "f1": f1_score(labels, predictions, average="weighted")
    }

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6280\2721217396.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# d:\Mentor\BankBot_AI\bankbot_ai\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='800' max='800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [800/800 14:01, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.017500</td>
#     </tr>
#   </tbody>
# </table><p>
# d:\Mentor\BankBot_AI\bankbot_ai\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# TrainOutput(global_step=800, training_loss=0.011462071053683758, metrics={'train_runtime': 842.0906, 'train_samples_per_second': 7.6, 'train_steps_per_second': 0.95, 'total_flos': 29806227763200.0, 'train_loss': 0.011462071053683758, 'epoch': 100.0})

# %%
def predict_intent(text):
    inputs = tokenizer(text, return_tensors="pt")

    with torch.no_grad():
        outputs = model(**inputs)

    probs = torch.softmax(outputs.logits, dim=1)
    pred_id = torch.argmax(probs).item()

    return {
        "intent": id2label[pred_id],
        "confidence": probs[0][pred_id].item()
    }

# %%
predict_intent("I want to block my debit card")
# Out:
# {'intent': 'card_block', 'confidence': 0.9990116357803345}

# %%
predict_intent("Please transfer $250 to my friend")
# Out:
# {'intent': 'transfer_money', 'confidence': 0.9976254105567932}

# %%
predict_intent("How can I open a new savings account?")
# Out:
# {'intent': 'check_balance', 'confidence': 0.8916006088256836}

# %%
predict_intent("transfer 500 dollars to john")
# Out:
# {'intent': 'transfer_money', 'confidence': 0.9984286427497864}
